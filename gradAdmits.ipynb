# %% [markdown]
# # Graduate Admissions Analysis
#
# This file predicts the admissions of student in graduate programs based on certain parameters like Exam Scores, SOP, LOR, CGPA, university rating and Research

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
admission=pd.read_csv('Admission_Predict.csv')

# %% [markdown]
# ### Check schema of data and if there are any missing values

# %%
admission.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
admission.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
admission.isnull().any()
# Out:
# Serial No.           False
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %%
admission.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
admission.shape
# Out:
# (400, 9)

# %% [markdown]
# ### Run general statistics

# %%
admission['GRE Score'].describe()
# Out:
# count    400.000000
# mean     316.807500
# std       11.473646
# min      290.000000
# 25%      308.000000
# 50%      317.000000
# 75%      325.000000
# max      340.000000
# Name: GRE Score, dtype: float64

# %%
admission['TOEFL Score'].describe()
# Out:
# count    400.000000
# mean     107.410000
# std        6.069514
# min       92.000000
# 25%      103.000000
# 50%      107.000000
# 75%      112.000000
# max      120.000000
# Name: TOEFL Score, dtype: float64

# %% [markdown]
# ### Data Exploration using matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(admission['CGPA'].values, admission['Chance of Admit '].values)

# %%
plt.scatter(admission['TOEFL Score'].values, admission['Chance of Admit '].values)

# %%
plt.scatter(admission['GRE Score'].values, admission['Chance of Admit '].values)

# %% [markdown]
# ### People with research work got more admits

# %%
plt.scatter(admission['Research'].values, admission['Chance of Admit '].values)

# %% [markdown]
# ### correlation heatmap

# %%
sns.heatmap(admission.corr(),annot=True,fmt= '.2f')
